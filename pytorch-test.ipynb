# %%
import torch

# %%
import math

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Radeon RX 7900 XTX'

# %%
dtype = torch.float

# %%
device = torch.device("cuda:0")

# %%
learning_rate = 1e-6
